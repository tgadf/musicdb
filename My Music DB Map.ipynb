# %% [markdown]
# # Interactive Music DB Notebook

# %%
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>

# %%
# %load_ext autoreload
# %autoreload
from myMusicDBMap import myMusicDBMap
from artistDB import artistDB
from musicData import musicData
from timeUtils import clock, elapsed
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from musicArtistData import musicArtistData
tmp = musicArtistData("HI")
key = "SOURCE"
val = {"DB": 3403}
tmp.addDBData(key, val)
tmp.__dict__
# Out:
# {'discname': 'HI',
#  'usethe': False,
#  'bands': [],
#  'dbdata': {'SOURCE': <musicDBData.musicDBData at 0x7fa60cca0bd0>},
#  'alias': [],
#  'renames': [],
#  'debug': False}

# %%
# !python setup.py install
# Out:
# running install
# ===> Copying [/Users/tgadfort/opt/anaconda3/envs/py37/musicdb/myMusicMap.p] to [myMusicMap.p] to avoid overwritting the subsequent reverse copy
# ===> Copying [/Users/tgadfort/opt/anaconda3/envs/py37/musicdb/musicData.p] to [musicData.p] to avoid overwritting the subsequent reverse copy
# running build
# running build_py
# copying musicData.py -> build/lib
# copying musicArtistData.py -> build/lib
# running install_lib
# copying build/lib/musicData.py -> /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages
# copying build/lib/musicArtistData.py -> /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages
# byte-compiling /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/musicData.py to musicData.cpython-37.pyc
# byte-compiling /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/musicArtistData.py to musicArtistData.cpython-37.pyc
# running install_data
# copying myMusicMap.p -> /Users/tgadfort/opt/anaconda3/envs/py37/musicdb
# running install_egg_info
# running egg_info
# writing musicdb.egg-info/PKG-INFO
# writing dependency_links to musicdb.egg-info/dependency_links.txt
# writing requirements to musicdb.egg-info/requires.txt
# writing top-level names to musicdb.egg-info/top_level.txt
# reading manifest file 'musicdb.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'musicdb.egg-info/SOURCES.txt'
# removing '/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/musicdb-0.0.1-py3.7.egg-info' (and everything under it)
# Copying musicdb.egg-info to /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/musicdb-0.0.1-py3.7.egg-info
# running install_scripts

# %% [markdown]
# # Get Full DB

# %%
mdb = myMusicDBMap(debug=True, overwrite=False)
mydb = mdb.get()
mdb.getFullDBData()
# Out:
# Creating myMusicDBMap()
#    Loading my music db map: /Users/tgadfort/opt/anaconda3/envs/py37/musicdb/myMusicMap.p
#    DB keys: ['Discogs', 'AllMusic', 'MusicBrainz', 'AceBootlegs', 'RateYourMusic', 'LastFM', 'DatPiff', 'RockCorner', 'CDandLP', 'MusicStack', 'MetalStorm']
# Found 4763 artist entries
# Counter({'Discogs': 4624, 'AllMusic': 4512, 'MusicBrainz': 4273, 'LastFM': 3415, 'CDandLP': 760, 'RockCorner': 551, 'DatPiff': 518, 'AceBootlegs': 176, 'RateYourMusic': 65, 'MusicStack': 4, 'MetalStorm': 0})
# Counter({'Discogs': 4624, 'AllMusic': 4512, 'MusicBrainz': 4273, 'LastFM': 3415, 'CDandLP': 760, 'RockCorner': 551, 'DatPiff': 518, 'AceBootlegs': 176, 'RateYourMusic': 65, 'MusicStack': 4, 'MetalStorm': 0})
# Found 4763 artist entries
# Counter({'Discogs': 4624, 'AllMusic': 4512, 'MusicBrainz': 4273, 'LastFM': 3415, 'CDandLP': 760, 'RockCorner': 551, 'DatPiff': 518, 'AceBootlegs': 176, 'RateYourMusic': 65, 'MusicStack': 4, 'MetalStorm': 0})
# Getting Database Data For Discogs
# Getting DB Data For Discogs
# =========================   discogs   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (Discogs)
#     Found 752449 Artists in DB
#     Found 752449 ID -> Name entries
#     Found 687084 Name -> ID entries
#   Getting Master Artist Album DB File (Discogs)
#     Found 752449 Artist Albums
# Summary Statistics For DB: Discogs
#     Using Known Artists: False
#     Found 752449 ID -> Name entries
#     Found 687084 Name -> ID entries
#     Found 0 Albums
# Getting Database Data For AllMusic
# Getting DB Data For AllMusic
# =========================   allmusic   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (AllMusic)
#     Found 54014 Artists in DB
#     Found 54014 ID -> Name entries
#     Found 50150 Name -> ID entries
#   Getting Master Artist Album DB File (AllMusic)
#     Found 54014 Artist Albums
# Summary Statistics For DB: AllMusic
#     Using Known Artists: False
#     Found 54014 ID -> Name entries
#     Found 50150 Name -> ID entries
#     Found 229101 Albums
# Getting Database Data For MusicBrainz
# Getting DB Data For MusicBrainz
# =========================   musicbrainz   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (MusicBrainz)
#     Found 133914 Artists in DB
#     Found 133914 ID -> Name entries
#     Found 112971 Name -> ID entries
#   Getting Master Artist Album DB File (MusicBrainz)
#     Found 133914 Artist Albums
# Summary Statistics For DB: MusicBrainz
#     Using Known Artists: False
#     Found 133914 ID -> Name entries
#     Found 112971 Name -> ID entries
#     Found 0 Albums
# Getting Database Data For AceBootlegs
# Getting DB Data For AceBootlegs
# =========================   acebootlegs   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (AceBootlegs)
#     Found 341 Artists in DB
#     Found 341 ID -> Name entries
#     Found 341 Name -> ID entries
#   Getting Master Artist Album DB File (AceBootlegs)
#     Found 341 Artist Albums
# Summary Statistics For DB: AceBootlegs
#     Using Known Artists: False
#     Found 341 ID -> Name entries
#     Found 341 Name -> ID entries
#     Found 2838 Albums
# Getting Database Data For RateYourMusic
# Getting DB Data For RateYourMusic
# =========================   rateyourmusic   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (RateYourMusic)
#     Found 77 Artists in DB
#     Found 77 ID -> Name entries
#     Found 76 Name -> ID entries
#   Getting Master Artist Album DB File (RateYourMusic)
#     Found 77 Artist Albums
# Summary Statistics For DB: RateYourMusic
#     Using Known Artists: False
#     Found 77 ID -> Name entries
#     Found 76 Name -> ID entries
#     Found 0 Albums
# Getting Database Data For LastFM
# Getting DB Data For LastFM
# =========================   lastfm   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (LastFM)
#     Found 113113 Artists in DB
#     Found 113113 ID -> Name entries
#     Found 112951 Name -> ID entries
#   Getting Master Artist Album DB File (LastFM)
#     Found 113113 Artist Albums
# Summary Statistics For DB: LastFM
#     Using Known Artists: False
#     Found 113113 ID -> Name entries
#     Found 112951 Name -> ID entries
#     Found 972218 Albums
# Getting Database Data For DatPiff
# Getting DB Data For DatPiff
# =========================   datpiff   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (DatPiff)
#     Found 44209 Artists in DB
#     Found 44209 ID -> Name entries
#     Found 44185 Name -> ID entries
#   Getting Master Artist Album DB File (DatPiff)
#     Found 44209 Artist Albums
# Summary Statistics For DB: DatPiff
#     Using Known Artists: False
#     Found 44209 ID -> Name entries
#     Found 44185 Name -> ID entries
#     Found 125386 Albums
# Getting Database Data For RockCorner
# Getting DB Data For RockCorner
# =========================   rockcorner   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (RockCorner)
#     Found 1262 Artists in DB
#     Found 1262 ID -> Name entries
#     Found 1262 Name -> ID entries
#   Getting Master Artist Album DB File (RockCorner)
#     Found 1262 Artist Albums
# Summary Statistics For DB: RockCorner
#     Using Known Artists: False
#     Found 1262 ID -> Name entries
#     Found 1262 Name -> ID entries
#     Found 14481 Albums
# Getting Database Data For CDandLP
# Getting DB Data For CDandLP
# =========================   cdandlp   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (CDandLP)
#     Found 4977 Artists in DB
#     Found 4977 ID -> Name entries
#     Found 4936 Name -> ID entries
#   Getting Master Artist Album DB File (CDandLP)
#     Found 4977 Artist Albums
# Summary Statistics For DB: CDandLP
#     Using Known Artists: False
#     Found 4977 ID -> Name entries
#     Found 4936 Name -> ID entries
#     Found 39600 Albums
# Getting Database Data For MusicStack
# Getting DB Data For MusicStack
# =========================   musicstack   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (MusicStack)
#     Found 187 Artists in DB
#     Found 187 ID -> Name entries
#     Found 186 Name -> ID entries
#   Getting Master Artist Album DB File (MusicStack)
#     Found 187 Artist Albums
# Summary Statistics For DB: MusicStack
#     Using Known Artists: False
#     Found 187 ID -> Name entries
#     Found 186 Name -> ID entries
#     Found 579 Albums
# Getting Database Data For MetalStorm
# Getting DB Data For MetalStorm
# =========================   metalstorm   =========================
# Getting All Artist DB Data
#   Getting Master Artist DB File (MetalStorm)
#     Found 11 Artists in DB
#     Found 11 ID -> Name entries
#     Found 11 Name -> ID entries
#   Getting Master Artist Album DB File (MetalStorm)
#     Found 11 Artist Albums
# Summary Statistics For DB: MetalStorm
#     Using Known Artists: False
#     Found 11 ID -> Name entries
#     Found 11 Name -> ID entries
#     Found 43 Albums

# %% [markdown]
# # Find Artist Tests

# %%
artistNames = ["Bobb Seger", "AeroSMith", "2Pac", "David Matthews Band", "Kathy Perry", "Johnny Mayer", "Fleetwood Jack", "Nelly"]
num = 500
cutoff = 0.6 ## 22 seconds with 0.6, 18 seconds w/ 0.7, 10 seconds with 0.9, 7 seconds with 0.95, 5 seconds with 0.99

# %%
######################################################################
#### Get Potential DB Artists
######################################################################
start, cmt = clock("Getting Artist IDs for N = {0} ; CutOff = {1}".format(num, cutoff))
for artistName in artistNames:
    artistNameDBIDs = mdb.getArtistIDs(artistName, num=num, cutoff=cutoff)
elapsed(start, cmt)
# Out:
# Current Time is Mon Oct 26, 2020 17:44:39 for Getting Artist IDs for N = 500 ; CutOff = 0.6
# Current Time is Mon Oct 26, 2020 17:45:01 for Done with Getting Artist IDs for N = 500 ; CutOff = 0.6
# Process [Done with Getting Artist IDs for N = 500 ; CutOff = 0.6] took 22 seconds.

# %%
import textdistance

# %%
import textdistance

textdistance.hamming('test', 'text')
# 1

textdistance.hamming.distance('test', 'text')
# 1

textdistance.hamming.similarity('test', 'text')
# 3

textdistance.hamming.normalized_distance('test', 'text')
# 0.25

textdistance.hamming.normalized_similarity('test', 'text')
# 0.75

textdistance.Hamming(qval=2).distance('test', 'text')
# 2

# %%
:
            nearArtists = findNearest(artistName, self.getArtists(), num=num, cutoff=cutoff)
            if debug:
                print("Nearest Matches for: {0}".format(artistName))
            for nearArtist in nearArtists:
                artistIDs[nearArtist] = self.artistNameToID[nearArtist]
            return artistIDs

# %%
artistIDs = {db: mdb.dbdata[db].getArtistIDs(artistName, num, cutoff, debug=False) for db in mdb.getDBs()}

# %%
artistIDs
# Out:
# {'Discogs': {'Nelly': ['4968715',
#    '1278536',
#    '2592828',
#    '485756',
#    '1181639',
#    '2312089',
#    '3296635',
#    '7173060',
#    '1302213',
#    '1261338',
#    '51368']},
#  'AllMusic': {'Nelly': ['0000532094', '0000861351']},
#  'MusicBrainz': {'Nelly': ['244431813426963163028385703609674153669',
#    '203140431399694646117649158420119492009',
#    '194204208575207358051626734947270784329',
#    '115996425354626929285399621072230759086']},
#  'AceBootlegs': {},
#  'RateYourMusic': {},
#  'LastFM': {'Nelly': ['16286022230']},
#  'DatPiff': {'Nelly': ['6022230']},
#  'RockCorner': {},
#  'CDandLP': {'Nelly': ['50237092964598']},
#  'MusicStack': {},
#  'MetalStorm': {}}

# %%
artistNameDBIDs
# Out:
# {'Discogs': {'Bob Seger': ['267854'],
#   'Bobby Leger': ['1633644'],
#   'Bobby Steggert': ['5851871'],
#   'Bob Zieger': ['1493947'],
#   'Bob Zeiger': ['1329883'],
#   'Bob Sledge': ['3636698'],
#   'Bob Siegel': ['1923955'],
#   'Bob Sender': ['5423638'],
#   'Bob Seerbo': ['1903645'],
#   'Bob Boeger': ['4813374'],
#   'Bob Steineger': ['5480388'],
#   'Bobby Stern': ['1847827', '340410'],
#   'Bobby Sheen': ['389746'],
#   'Bob Ziegler': ['3279456'],
#   'Bob Stroger': ['1004950'],
#   'Bob Steeler': ['423034'],
#   'Bob Stagner': ['426143'],
#   'Bob Spencer': ['311296'],
#   'Bob Singers': ['322429'],
#   'Bob Siebert': ['2089863'],
#   'Bob Sheller': ['4747699'],
#   'Bob Sellers': ['196680'],
#   'Bob Metzger': ['272816'],
#   'Bobby Teenager': ['3262448'],
#   'Rob Reger': ['450387'],
#   'Bobby Vee': ['286807'],
#   'Bobby Lee': ['4058836',
#    '7904848',
#    '6299204',
#    '7016628',
#    '606401',
#    '5463624',
#    '3748365'],
#   'Bobb Deep': ['460739'],
#   'Bob Weber': ['1563515', '940689'],
#   'Bob Suber': ['593175'],
#   'Bob Stern': ['1877362'],
#   'Bob Sleep': ['5203131'],
#   'Bob Sfero': ['7014084'],
#   'Bob Saker': ['461261'],
#   'Bob Saget': ['2383116'],
#   'Bob Egger': ['3238231'],
#   'Bob Degen': ['328221'],
#   'Bob Beers': ['1368354'],
#   'Bob Beere': ['5483633'],
#   'Bob Auger': ['313649'],
#   'Bomb Shelter': ['2260958'],
#   'Bobby Summer': ['280019']},
#  'AllMusic': {'Bob Seger': ['0000072041'],
#   'Bobby Vee': ['0000077732'],
#   'Bob Seely': ['0001094097'],
#   'Bob Segarini': ['0000622505'],
#   'Bob Burger': ['0001578942']},
#  'MusicBrainz': {'Bob Seger': ['65535178462489404673029321173275608311'],
#   'Bob Kroeger': ['90168032279473105045552209752689782235'],
#   'Bobby Vee': ['101258356617641813919243301186729842186'],
#   'Bobb Deep': ['252338784537322547774854707056231633604'],
#   'Bob Degen': ['4332098137375005745683810626313582494'],
#   'Bob Auger': ['156835436066229167711354006978479708225'],
#   'Bobby Ranger': ['160293275559717903668520172217832421345'],
#   'Bobby Danger': ['274542552776637536441765881817095151680'],
#   'Bob Lee': ['65505634080280790644109111934203691295'],
#   'Tao Seeger': ['252898067300248349812572271977433237346'],
#   'Bobby Shew': ['325168519012346548333092695581550696617'],
#   'Bobby Peru': ['266186831306900875445764421015223113576'],
#   'Bob Snider': ['213230422753384508509405456846867456123'],
#   'Bob Shaver': ['205428201521525116622600553714196938250'],
#   'Bob Seeley': ['101569558776820412407016360522555232886'],
#   'Bob Burger': ['79885204424545822084656811666901860996']},
#  'AceBootlegs': {},
#  'RateYourMusic': {'Bob Seger': ['7900']},
#  'LastFM': {'Bob Seger': ['31718859749'], 'Bob Seeley': ['9125278720']},
#  'DatPiff': {'Robb Skee': ['6146748']},
#  'RockCorner': {'Bob Seger': ['718859749']},
#  'CDandLP': {'Bobby Stringer': ['35708956172906']},
#  'MusicStack': {},
#  'MetalStorm': {}}

# %%
######################################################################
#### Get Database Albums
######################################################################
matches = {}
for db,artistDBartists in artistNameDBIDs.items():

    dbMatches = {}
    for artistDBartist,artistDBIDs in artistDBartists.items():
        for artistDBID in artistDBIDs:
            dbMatches[artistDBID] = {}
            artistDBAlbumsFromID = self.mdb.getArtistAlbumsFromID(db, artistDBID)

            for mediaType, mediaTypeAlbums in artistDBAlbumsFromID.items():
                if albumType is not None:
                    if mediaType not in self.mdb.getDBAlbumTypeNames(db, albumType):
                        continue

                ma = matchAlbums(cutoff=ratioCut)
                ma.match(chartArtistAlbums, mediaTypeAlbums)
                #ma.show(debug=True)

                dbMatches[artistDBID][mediaType] = ma

    matches[db] = dbMatches

# %% [markdown]
# # Chart DB

# %%
cdb = {'Ray Price': {'AceBootlegs': None,
  'AllMusic': '0000409954',
  'CDandLP': None,
  'DatPiff': '9626463',
  'Discogs': '311678',
  'LastFM': '23601230928',
  'MetalStorm': None,
  'MusicBrainz': '284762534266269933722691506502461226012',
  'MusicStack': None,
  'RateYourMusic': None,
  'RockCorner': None}}

# %%
md = musicData()
md.setMusicDBData(mdb)
# Out:
# Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicdb/musicData.p
#   --> This file is 816.5kB.
# Loading /Users/tgadfort/opt/anaconda3/envs/py37/musicdb/musicData.p
# Found 4490 artist entries
# Counter({'Discogs': 4384, 'AllMusic': 4248, 'MusicBrainz': 4067, 'LastFM': 3330, 'CDandLP': 759, 'DatPiff': 553, 'RockCorner': 515, 'AceBootlegs': 179, 'RateYourMusic': 68, 'MusicStack': 5, 'MetalStorm': 0})

# %%
md.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-c7c36053ef65> in <module>
# ----> 1 md.summary()
#
# AttributeError: 'musicData' object has no attribute 'summary'

# %%
md.setChartData("Top40", cdb)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c2e8e08ec34a> in <module>
# ----> 1 md.setChartData("Top40", cdb)
#
# ~/Documents/code/musicdb/musicData.py in setChartData(self, chart, chartData)
#      25                 if self.artists.get(artistName) is None:
#      26                     self.artists[artistName] = musicArtistData(discname=artistName)
# ---> 27                 self.artists[artistName].addChartData(chart, artistChartData)
#      28         else:
#      29             raise ValueError("Must pass music dict")
#
# ~/Documents/code/musicdb/musicData.py in addChartData(self, chart, chartdata)
#     111
#     112     def addChartData(self, chart, chartdata):
# --> 113         if self.chartdb.get(chart) is None:
#     114             self.chartdb[chart] = None
#     115         self.chartdb[chart] = chartdata
#
# AttributeError: 'musicArtistData' object has no attribute 'chartdb'

# %%
ifile="/Users/tgadfort/opt/anaconda3/envs/py37/musicdb/myMusicMap.p"
ifile="myMusicMap.p"
from ioUtils import getFile
db = getFile(ifile)

# %%
mdb.getArtistData("Joey Lawrence")

# %%
mdb.add("Tammy Wynette", "AllMusic", "0000136640")
mdb.save()

# %%
# %load_ext autoreload
# %autoreload
from myMusicDBMap import myMusicDBMap
from artistDB import artistDB

myMusicMap = mdb.get()
#mdb.getFullDBData()
#mdb.getKnownDBData()

# %% [markdown]
# # Master Music DB

# %%
md = musicData()
md.setMusicDBData(mdb)
#md.save()

# %% [markdown]
# # Check For Incorrect DBDID

# %%
mdbdata = mdb.get()
for artist in mdbdata.keys():
    artistData = mdbdata[artist]
    for db in artistData.keys():
        dbdata = artistData[db]
        if isinstance(dbdata, dict):
            dbID = dbdata['ID']
            if dbID is None:
                print("mdb.add(\"{0}\", \"{1}\", None)".format(artist, db))
                continue
            try:
                int(dbID)
            except:
                print("mdb.add(\"{0}\", \"{1}\", \"{2}\")".format(artist, db, dbID))
                pass

# %%
mdb.add("Razorlight", "AllMusic", "0000577383")
mdb.add("Frank Jordan", "Discogs", None)
mdb.add("Pacifier", "AllMusic", '0000006045')
#mdb.save()

# %%
mdb.getNearestArtistNames("Lorde")

# %%
name = "Lorde"
amdb = mdb.dbdata["AllMusic"]
artists = sorted(amdb.getArtists())
#artists
from searchUtils import findNearest
#findNearest(name, artists, num=1, cutoff=0.9)
vals = [v for k,v in mdb.getNearestArtistNames(name, cutoff=0.9).items() if v is not None]
vals

# %%
amdb.summary()

# %%
for name in list(names.keys()):
    print(name)
    vals = mdb.getNearestArtistNames(name, cutoff=0.1)
    print("\t",vals)
    print("\n\n")

# %%
mdb.getNearestArtistNames("Porno Graffiti", cutoff=0.8)

# %%
IDs = ['0001196347', '0000691561','0001711295', '0000952169', '0000112185','0000340152','0000742409']

# %%
names = []
for dbID in IDs:
    db,artistName = mdb.getArtistFromID(dbID)
    names.append(artistName)
names

# %%
dbdata = mdb.getDBData("AllMusic")

# %%
mdb.getDBMatches('Discogs')

# %%
dbdata.artistIDToName.keys()

# %%
#mdb.add("West, Space and Love", "Discogs", "5137906")
#mdb.add("Aetherian", "Discogs", "5085327")
mdb.add("DVSN", "AllMusic", "0003488294")

# %%
mdb.rmArtistDBKey("Aetherian", "AllMusic")
mdb.rmArtistDBKey("Aetherian", "LastFM")

# %%
mdb.rmArtistDBKey("Neil Diamond", "Discogs")
#

# %%
mdb.add("Neil Diamond", "Discogs", "271516")
mdb.add("Neil Diamond", "AllMusic", '0000864209')

# %%
mdb.rmArtistDBKey("LeAnn Rimes", "LastFM")
#mdb.add("LeAnn Rimes", "AllMusic", '0000118791')
#0000246487

# %%
{'PM': ['/Volumes/Piggy/Music/Matched/P/PM'],
 'Qango': ['/Volumes/Piggy/Music/Matched/Q/Qango'],
 'The Gimmme Caps': ['/Volumes/Piggy/Music/Matched/The/The Gimmme Caps'],
 'Yazoo': ['/Volumes/Piggy/Music/Matched/Y/Yazoo']}

# %%
mdb.add("PM", "Discogs", "2559390")
mdb.add("Qango", "Discogs", "3136110")
#mdb.add("The Gimmme Caps", "Discogs", "271516")
mdb.add("Yazoo", "Discogs", "2713")

# %%
mdb.save()
#mn0000073644

# %%
# !python setup.py install

# %% [markdown]
# # Manual Edits

# %%
mdb.saveYAML()

# %%
Artist ID [0001196347] is not found in Albums DB [AllMusic]
Artist ID [0000691561] is not found in Albums DB [AllMusic]
Artist ID [0001711295] is not found in Albums DB [AllMusic]
Artist ID [0000952169] is not found in Albums DB [AllMusic]
Artist ID [0000112185] is not found in Albums DB [AllMusic]
Artist ID [0000340152] is not found in Albums DB [AllMusic]
Artist ID [0000742409] is not found in Albums DB [AllMusic]

# %%
mdb.readYAML()

# %%
dbname = "AllMusic"
mydbdata = {artistName: db.get(dbname) for artistName, db in mydb.items() if db.get(dbname) is not None}
mydbdata = {artistName: dbdata.get("ID") for artistName, dbdata in mydbdata.items() if dbdata.get("ID") is not None}

# %%
from masterdb import getArtistAlbumsDB
from discogsBase import discogs
disc = discogs("allmusic")
artistAlbumsDB = getArtistAlbumsDB(disc, force=False).to_dict()

# %%
knownIDs = list(mydbdata.values())
print(len(artistAlbumsDB["Albums"]))
subset = {artistID: artistData for artistID,artistData in artistAlbumsDB["Albums"].items() if artistID in knownIDs}
print(len(subset))

# %% [markdown]
# ## Initialize a Database

# %%
tmp = mdb.rmKey("MetalStorm")
tmp = mdb.initKey("MetalStorm")

# %% [markdown]
# ## Remove a Database

# %%
tmp = mdb.rmKey("Dummy")

# %% [markdown]
# ## Save all records

# %%
mdb.save()

# %% [markdown]
# ## Get all database data

# %%
myMusicMap = mdb.get()
#mdb.getFullDBData()
mdb.getKnownDBData()

# %% [markdown]
# # Merge Database Data

# %%
retval

# %%
if len(retval) > 0:
    for artistName,artistResult in retval.items():
        for db,dbResult in artistResult.items():
            mdb.add(artistName, db, dbResult["ID"])
    mdb.save()

# %% [markdown]
# # Manually Add Artist

# %%
artistName = "Gerry Rafferty"
db  = "AllMusic"
val = {'ID': '0000945196', 'Score': [2, 10.161, 1.0]}
mdb.addArtist(artistName)

# %%
#mdb.getArtistIDs("John MayerX", cutoff=0.2)

# %%
#mdb.getArtistAlbumsFromID(db='AllMusic', artistID='0000239827')
