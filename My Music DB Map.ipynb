# %%
from myMusicDBMap import myMusicDBMap

# %%
mdb = myMusicDBMap()

# %%
mdb.show()
# Out:
# Counter({'Discogs': 3851, 'AllMusic': 3760, 'MusicBrainz': 3622, 'LastFM': 1480, 'AceBootlegs': 80, 'DatPiff': 56, 'RateYourMusic': 22})

# %%
myMusicMap = mdb.initKey("RockCorner")

# %%
mdb.save(myMusicMap)
# Out:
# Counter({'Discogs': 3851, 'AllMusic': 3760, 'MusicBrainz': 3622, 'LastFM': 1480, 'AceBootlegs': 80, 'DatPiff': 56, 'RateYourMusic': 22})
# Saving data to myMusicMap.p
#   --> This file is 294.7kB.
# Saved data to myMusicMap.p
#   --> This file is 294.7kB.

# %%
mdb.show()
# Out:
# Counter({'Discogs': 3851, 'AllMusic': 3760, 'MusicBrainz': 3622, 'LastFM': 1480, 'AceBootlegs': 80, 'DatPiff': 56, 'RateYourMusic': 22})
