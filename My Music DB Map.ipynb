# %% [markdown]
# # Interactive Music DB Notebook

# %%
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>

# %%
# %load_ext autoreload
# %autoreload
from myMusicDBMap import myMusicDBMap
from artistDB import artistDB
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mdb = myMusicDBMap(debug=True)
# Out:
# Creating myMusicDBMap()
# /Users/tgadfort/Documents/code/musicdb
#    Loading my music db map: /anaconda3/envs/py37/musicdb/myMusicMap.p
#    DB keys: ['Discogs', 'AllMusic', 'MusicBrainz', 'AceBootlegs', 'RateYourMusic', 'LastFM', 'DatPiff', 'RockCorner', 'CDandLP', 'MusicStack']
# Counter({'Discogs': 3851, 'AllMusic': 3760, 'MusicBrainz': 3622, 'LastFM': 2767, 'DatPiff': 439, 'RockCorner': 313, 'AceBootlegs': 162, 'CDandLP': 66, 'RateYourMusic': 25, 'MusicStack': 5})

# %%
myMusicMap = mdb.get()
# Out:
# Found 3942 artist entries
# Counter({'Discogs': 3851, 'AllMusic': 3760, 'MusicBrainz': 3622, 'LastFM': 2767, 'DatPiff': 439, 'RockCorner': 313, 'AceBootlegs': 162, 'CDandLP': 66, 'RateYourMusic': 25, 'MusicStack': 5})

# %%
dbdata = mdb.getDBData("RockCorner")
# Out:
# Getting Database Data For RockCorner
# Getting DB Data For RockCorner
#   Getting Master Artist DB File (RockCorner)
#     Found 1078 Artists in DB
#     Found 1078 ID -> Name entries
#     Found 1078 Name -> ID entries
#   Getting Master Artist Album DB File (RockCorner)
# Current Time is Mon Apr 06, 2020 00:01:21 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Mon Apr 06, 2020 00:01:21 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 276.0 millseconds.
#     Found 1 Artist Albums
# Summary Statistics For DB: RockCorner
#     Found 1078 Artists in DB
#     Found 1078 ID -> Name entries
#     Found 1078 Name -> ID entries
#     Found 1078 Artists with Albums
#     Found 12531 Albums

# %%
adb = dbdata.albumsDB

# %%
# Out:
# 12531

# %%
[sum([v2 for v2 in v.values()]) for k,v in adb.items()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-d162e04259d5> in <module>
# ----> 1 [sum([v2 for v2 in v.values()]) for k,v in adb.items()]
#
# <ipython-input-145-d162e04259d5> in <listcomp>(.0)
# ----> 1 [sum([v2 for v2 in v.values()]) for k,v in adb.items()]
#
# TypeError: unsupported operand type(s) for +: 'int' and 'dict'

# %%
adb = artistDB("CDandLP")
# Out:
# Current Time is Sun Apr 05, 2020 23:03:27 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:03:27 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 68.0 millseconds.
# Summary Statistics For DB: CDandLP
#     Found 494 Artists in DB
#     Found 494 ID -> Name entries
#     Found 494 Name -> ID entries
#     Found 494 Artists with Albums
#     Found 3585 Albums

# %%
mdb = myMusicDBMap(debug=True)
# Out:
# Creating myMusicDBMap()
# /Users/tgadfort/Documents/code/musicdb
#    Loading my music db map: /anaconda3/envs/py37/musicdb/myMusicMap.p
#    DB keys: ['Discogs', 'AllMusic', 'MusicBrainz', 'AceBootlegs', 'RateYourMusic', 'LastFM', 'DatPiff', 'RockCorner', 'CDandLP', 'MusicStack']
# Counter({'Discogs': 3851, 'AllMusic': 3760, 'MusicBrainz': 3622, 'LastFM': 2767, 'DatPiff': 439, 'RockCorner': 313, 'AceBootlegs': 162, 'CDandLP': 66, 'RateYourMusic': 25, 'MusicStack': 5})

# %%
mdb.getDBData()
# Out:
# Current Time is Sun Apr 05, 2020 23:22:52 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:23:47 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 55 seconds.
# Summary Statistics For DB: Discogs
#     Found 718453 Artists in DB
#     Found 718453 ID -> Name entries
#     Found 660198 Name -> ID entries
#     Found 718453 Artists with Albums
#     Found 3585 Albums
# Current Time is Sun Apr 05, 2020 23:23:48 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:23:50 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 1 seconds.
# Summary Statistics For DB: AllMusic
#     Found 38677 Artists in DB
#     Found 38677 ID -> Name entries
#     Found 36388 Name -> ID entries
#     Found 38677 Artists with Albums
#     Found 3585 Albums
# Current Time is Sun Apr 05, 2020 23:23:50 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:23:52 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 1 seconds.
# Summary Statistics For DB: MusicBrainz
#     Found 55245 Artists in DB
#     Found 55245 ID -> Name entries
#     Found 44692 Name -> ID entries
#     Found 55245 Artists with Albums
#     Found 3585 Albums
# Current Time is Sun Apr 05, 2020 23:23:52 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:23:52 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 21.0 millseconds.
# Summary Statistics For DB: AceBootlegs
#     Found 341 Artists in DB
#     Found 341 ID -> Name entries
#     Found 341 Name -> ID entries
#     Found 341 Artists with Albums
#     Found 3585 Albums
# Current Time is Sun Apr 05, 2020 23:23:52 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:23:52 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 54.0 millseconds.
# Summary Statistics For DB: RateYourMusic
#     Found 39 Artists in DB
#     Found 39 ID -> Name entries
#     Found 38 Name -> ID entries
#     Found 39 Artists with Albums
#     Found 3585 Albums
# Current Time is Sun Apr 05, 2020 23:23:52 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:23:53 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 426.0 millseconds.
# Summary Statistics For DB: LastFM
#     Found 48049 Artists in DB
#     Found 48049 ID -> Name entries
#     Found 47944 Name -> ID entries
#     Found 48049 Artists with Albums
#     Found 3585 Albums
# Current Time is Sun Apr 05, 2020 23:23:53 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:23:54 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 546.0 millseconds.
# Summary Statistics For DB: DatPiff
#     Found 44170 Artists in DB
#     Found 44170 ID -> Name entries
#     Found 44146 Name -> ID entries
#     Found 44170 Artists with Albums
#     Found 3585 Albums
# Current Time is Sun Apr 05, 2020 23:23:54 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:23:54 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 208.0 millseconds.
# Summary Statistics For DB: RockCorner
#     Found 1078 Artists in DB
#     Found 1078 ID -> Name entries
#     Found 1078 Name -> ID entries
#     Found 1078 Artists with Albums
#     Found 3585 Albums
# Current Time is Sun Apr 05, 2020 23:23:54 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:23:54 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 36.0 millseconds.
# Summary Statistics For DB: CDandLP
#     Found 494 Artists in DB
#     Found 494 ID -> Name entries
#     Found 494 Name -> ID entries
#     Found 494 Artists with Albums
#     Found 3585 Albums
# Current Time is Sun Apr 05, 2020 23:23:54 for
# =================================== Creating Artist Albums DB ===================================
# Using previously created Artist Albums DB
# Current Time is Sun Apr 05, 2020 23:23:54 for Done with
# =================================== Creating Artist Albums DB ===================================
# Process [Done with
# =================================== Creating Artist Albums DB ===================================] took 13.0 millseconds.
# Summary Statistics For DB: MusicStack
#     Found 187 Artists in DB
#     Found 187 ID -> Name entries
#     Found 186 Name -> ID entries
#     Found 187 Artists with Albums
#     Found 3585 Albums

# %%
mdb.dbdata["MusicStack"].albumsDB
# Out:
# {'574300': {'MixTape': {'5653704': 'Pierced Pussy Lips'}},
#  '8962700': {'MixTape': {'6636854': 'Commando Of Love',
#    '4627659': 'Total Anal'}},
#  '9790801': {'MixTape': {'7790478': 'Jesus, He Brings Me Joy'}},
#  '7623910': {'MixTape': {'7814021': 'Analia Y Los Accesorios'}},
#  '5562310': {'MixTape': {'7161584': 'Supersloop'}},
#  '1912010': {'MixTape': {'4878139': 'Welcome To My House !'}},
#  '512810': {'MixTape': {'276956': 'Dreaming Of Detroit'}},
#  '769511': {'MixTape': {'8514272': 'Audio Santo',
#    '2227604': 'Ball Banger',
#    '1780634': 'Extendet Memorys',
#    '6099331': 'Future',
#    '179203': 'Hanging Myself Comfortably',
#    '1714437': 'J',
#    '5472406': 'Psycho Bitch From Hell',
#    '6062073': 'Space Walk',
#    '6417334': 'Tantra Trance',
#    '7931307': "Trance'n Roll",
#    '2730074': 'Underground',
#    '8490490': 'Vinyl Trax'}},
#  '6149211': {'MixTape': {'7495080': 'Funky Mother'}},
#  '3061911': {'MixTape': {'746537': 'Geographic Excursion',
#    '7267189': 'Swayex'}},
#  '8097211': {'MixTape': {'393774': 'Daneben'}},
#  '7583311': {'MixTape': {'335212': 'Believe In Me'}},
#  '4322112': {'MixTape': {'654686': 'Communicate In Analog',
#    '7219245': 'Under The Influence'}},
#  '7496913': {'MixTape': {'3909056': 'Aquafortis'}},
#  '8639213': {'MixTape': {'182667': 'Abbey Road Relived',
#    '10701': 'The White Album'}},
#  '1874413': {'MixTape': {'6323743': 'Summoning The Wretched'}},
#  '3222416': {'MixTape': {'2537214': 'Skammen'}},
#  '881317': {'MixTape': {'6118152': 'Gozando'}},
#  '3815818': {'MixTape': {'7423647': 'Film Schieben'}},
#  '9973418': {'MixTape': {'8245343': 'Glastine', '5837698': 'Mama Africa'}},
#  '7875818': {'MixTape': {'4331288': 'A Fine Adjustment Of Time'}},
#  '6868619': {'MixTape': {'558575': 'Go',
#    '8546007': 'Puffin Billy Butlin',
#    '8671360': 'We, The Dreg',
#    '8742036': 'Ensure Your Needle Is Clean And Free Of Dust',
#    '5557408': "Being 'all The Rage' At Snidey Dave's Mobile Disco",
#    '8504498': 'Split',
#    '9920745': 'Bungles, Grumbles, A Game Of Bowls',
#    '3216201': 'Live At Bovington Camp Bournemouth'}},
#  '1784919': {'MixTape': {'3920485': 'Rose Rouge',
#    '4583256': 'Walking In Harlem',
#    '9821489': 'Circus',
#    '8108148': "Just Won't Do"}},
#  '3517702': {'MixTape': {'3710138': 'Damage Dealers'}},
#  '2900102': {'MixTape': {'8526285': '1984 And 1997',
#    '3180124': '303 And Chill',
#    '2600700': 'Aftermath Ii',
#    '1976273': 'Dimension Part One',
#    '2475783': 'Dinsync',
#    '3742376': 'The Exchange Session',
#    '5071852': 'Grown',
#    '2944741': 'Home',
#    '4674541': 'Home Versions',
#    '8069478': 'Made In Space',
#    '2869571': 'Midnight Til Noon',
#    '5934225': 'Patterns 56',
#    '226953': 'Roden Crater Vision',
#    '3132050': 'Timespaceroom',
#    '4065293': 'Watchdog',
#    '283905': 'Modulor Matador'}},
#  '1998702': {'MixTape': {'283905': 'Modulor Matador'}},
#  '5454020': {'MixTape': {'4338440': 'Acoustic And Ambient'}},
#  '1724421': {'MixTape': {'8504498': 'Split'}},
#  '1524721': {'MixTape': {'6168557': 'Best Democracy',
#    '1205013': 'Live To Air',
#    '5400860': 'Tiptoe Through The Roses'}},
#  '987923': {'MixTape': {'1160555': 'Ghost 45'}},
#  '4403323': {'MixTape': {'5021627': 'Live At Evolution Radar One',
#    '6810862': 'Live At The Evolution Radar One',
#    '9873881': 'Synthesis Addiction'}},
#  '2725023': {'MixTape': {'2943403': 'Take My Love'}},
#  '8002323': {'MixTape': {'7521015': 'Since You Came In'}},
#  '4641723': {'MixTape': {'4599986': 'Contraband',
#    '6760479': 'Dirty Little Thing',
#    '3011131': 'Fall To Pieces',
#    '8202724': "Rock And F' N Roll Across The Uk",
#    '8469480': 'Slither'}},
#  '6749124': {'MixTape': {'6251770': 'Zero Beats Per Minute'}},
#  '2892624': {'MixTape': {'1625897': 'Ka-ka!!',
#    '2865242': 'C ...is For Cookie!',
#    '5928912': 'Vegan Offensive',
#    '2892624': 'Anal Massaker'}},
#  '9021724': {'MixTape': {'4674018': 'Dolce Sogno'}},
#  '8052424': {'MixTape': {'907900': 'Sync To One'}},
#  '2905425': {'MixTape': {'634149': 'Analía Y Los Accesorios'}},
#  '8430525': {'MixTape': {'5518683': 'Strings Of Fire'}},
#  '7316826': {'MixTape': {'3776530': 'Beyond The Black Crack'}},
#  '888627': {'MixTape': {'7734598': 'Zonex'}},
#  '1478027': {'MixTape': {'7059925': "Feelin'"}},
#  '3643227': {'MixTape': {'4344343': 'Touch Me …'}},
#  '6823328': {'MixTape': {'5295878': 'Anal Blasphemy'}},
#  '5843628': {'MixTape': {'1169529': 'Two Cocks In The Same Hole'}},
#  '8001628': {'MixTape': {'870910': 'Red Revolution',
#    '4165763': 'Stench Like Six Demons'}},
#  '3548129': {'MixTape': {'6405805': 'Pop Music'}},
#  '5600229': {'MixTape': {'372344': 'The Flyby'}},
#  '7587129': {'MixTape': {'8663186': '99 Live',
#    '1299980': 'Cure Me...or Kill Me',
#    '7587129': 'Gilby Clarke',
#    '6653338': 'Rubber'}},
#  '3581230': {'MixTape': {'8922940': 'Black Ground',
#    '4986635': 'Featuring Alexander Robotnick And Ludus Pinsky'}},
#  '2542330': {'MixTape': {'6655129': '...punkt!',
#    '2118778': '1deutige2deutigkeiten',
#    '3734768': 'All Meine Headz',
#    '8020736': 'Ansichten',
#    '2403752': 'Rip Shit',
#    '3777919': 'Was Louz'}},
#  '8754331': {'MixTape': {'8108148': "Just Won't Do"}},
#  '7960934': {'MixTape': {'8454718': 'Death Drive'}},
#  '857036': {'MixTape': {'9920745': 'Bungles, Grumbles, A Game Of Bowls'}},
#  '8214236': {'MixTape': {'1893082': 'Happy Estella'}},
#  '7256136': {'MixTape': {'8837572': 'Rings Of Modulation'}},
#  '6475237': {'MixTape': {'774748': 'Pz'}},
#  '544437': {'MixTape': {'4699740': 'Oh Perfect Masters'}},
#  '591437': {'MixTape': {'9665098': 'For Tomorrow'}},
#  '4566737': {'MixTape': {'4856275': 'Somebody Knockin'}},
#  '9739038': {'MixTape': {'2127956': 'Cursory'}},
#  '613538': {'MixTape': {'8054898': 'Been There Lately',
#    '7868749': 'Beggars And Hangers'}},
#  '394604': {'MixTape': {'29269': 'Bird Lime',
#    '5810015': 'The Contention',
#    '9754502': 'It`s Truth !',
#    '5773984': 'Live'}},
#  '9347304': {'MixTape': {'7693543': 'Fulfilled Ambitions'}},
#  '5227140': {'MixTape': {'8417157': 'The First 100 Songs',
#    '2689474': 'That Makes Me Smart!'}},
#  '999541': {'MixTape': {'9286806': '110 Song',
#    '2358046': '40 More Reasons To Hate Us',
#    '7161869': '5643 Song',
#    '2305626': '88 Song',
#    '4369646': 'Dirty Rhymes And Psychotronic Beats',
#    '9575091': 'Everyone Should Be Killed',
#    '4789015': 'Morbid Florist',
#    '1489675': 'Old Stuff, Part Two',
#    '3510946': 'Picnic Of Love',
#    '814532': "Stayin' Alive",
#    '3189763': 'In These Black Days'}},
#  '4801542': {'MixTape': {'2892624': 'Anal Massaker'}},
#  '991442': {'MixTape': {'3271923': 'Dirty Sidewalk',
#    '6193275': 'Roofs',
#    '1803274': 'Tribute'}},
#  '2342842': {'MixTape': {'1063110': '25 Years Later',
#    '2342842': 'Analogy',
#    '6927969': 'The Complete Works',
#    '494188': 'Konzert',
#    '1659285': '[same]',
#    '5194926': 'The Suite',
#    '1141537': 'The Video Collection'}},
#  '9827243': {'MixTape': {'8742036': 'Ensure Your Needle Is Clean And Free Of Dust',
#    '3216201': 'Live At Bovington Camp Bournemouth'}},
#  '2075443': {'MixTape': {'5140177': 'Atto I°',
#    '4650735': 'Devotion',
#    '6038311': 'Icon',
#    '9992614': 'Inside Out',
#    '2899328': 'Pray For Your Future',
#    '7313726': 'Sound Of Frankfurt',
#    '5098834': 'Tie One On',
#    '1831553': 'Vol.2',
#    '9859572': 'Volume 5'}},
#  '743943': {'MixTape': {'743943': 'Analytica'}},
#  '166244': {'MixTape': {'4796040': 'Carbon Based',
#    '5190773': 'Inconstantinopolis'}},
#  '6882244': {'MixTape': {'6706098': 'Fundamentals'}},
#  '3828645': {'MixTape': {'1030456': 'Do You Wanna Mine',
#    '2648493': "I'll Take You There",
#    '2558833': "Sign O' The Times",
#    '2194668': 'To Be With You',
#    '4577451': 'Want U Baby'}},
#  '1523745': {'MixTape': {'8787583': 'Jugend Forscht',
#    '2097547': 'Kopfgeister'}},
#  '8798045': {'MixTape': {'2129745': 'All About Love',
#    '9893184': 'It Was All About Love'}},
#  '4584046': {'MixTape': {'5653704': 'Pierced Pussy Lips'}},
#  '4651346': {'MixTape': {'2674487': 'Electrofield',
#    '8145537': 'First Heading'}},
#  '8223946': {'MixTape': {'5712410': 'Controllers'}},
#  '8669146': {'MixTape': {'5395551': 'Double Talkin Jive'}},
#  '6978249': {'MixTape': {'1824324': 'Cats', '4984725': 'Sun Here I Come'}},
#  '6130850': {'MixTape': {'3776530': 'Beyond The Black Crack'}},
#  '9577051': {'MixTape': {'3240352': 'Rag Doll'}},
#  '3856852': {'MixTape': {'124608': 'Esfera'}},
#  '8310053': {'MixTape': {'1573136': 'Broken Pictures',
#    '1927954': 'Bye-bye',
#    '5765897': 'Lost In Emotion'}},
#  '481254': {'MixTape': {'7990328': 'Condom Of Hate'}},
#  '8323754': {'MixTape': {'7094269': 'Action Hunters',
#    '8621877': 'Desk Jockeys',
#    '3265030': 'Flimsy Output',
#    '6136761': 'Heavy Hands',
#    '5458484': 'Hot Brass Dance',
#    '2104726': 'In Plain Clothes',
#    '1778185': 'Les Perfumeries',
#    '1662673': 'Let The Music Play',
#    '1180293': 'Monkey Suits',
#    '4375231': 'Neukölln',
#    '4076929': 'Partytodance',
#    '2158047': 'Racoon City',
#    '191086': 'Unicorn',
#    '2127956': 'Cursory',
#    '774748': 'Pz'}},
#  '4243954': {'MixTape': {'9191409': 'Una Cancion No Es Suficiente'}},
#  '1939955': {'MixTape': {'3189763': 'In These Black Days'}},
#  '2903655': {'MixTape': {'7539937': 'Have A Hangover With'}},
#  '4218355': {'MixTape': {'9676009': 'Bewegexemplar'}},
#  '1125855': {'MixTape': {'5344443': 'Helmpflicht',
#    '1416334': 'Planet P',
#    '5638657': 'Pulse Width',
#    '2183358': 'Tricc 17',
#    '9461313': 'Zangenhand',
#    '8787583': 'Jugend Forscht',
#    '2097547': 'Kopfgeister'}},
#  '3885155': {'MixTape': {'4589837': '06.06.1992 Hippodrome De Vincennes',
#    '6502450': '1993-05-29',
#    '398775': '1994 2001',
#    '3791616': '1995 Calendar',
#    '6965319': '3rd Gig',
#    '2570488': '40+ Vhs U-pick',
#    '4703673': '44 Caliber Horticulture',
#    '1436640': 'Aargh !!!',
#    '4693984': 'Acoustic Jam',
#    '7400197': "Ain't It Fun",
#    '9867632': 'Album Sampler',
#    '5748738': 'Alternatives For Destruction',
#    '5291542': 'Apetite For Destruction',
#    '90971': 'Bad Obsession',
#    '5317251': 'Band Discography Magnet',
#    '23639': 'Banzai',
#    '7859767': 'Best Ballads',
#    '2842529': 'The Best Of',
#    '4424888': 'Better',
#    '9831843': "Bossa N' Roses",
#    '6638751': 'Broadcast Archive',
#    '8647348': 'California X',
#    '9323219': 'Chinese Democracy',
#    '7445176': 'The Chris Tetley Interviews',
#    '1285129': 'Civil War',
#    '1856702': 'Classic Airwaves',
#    '7359800': 'Comic Book',
#    '4633658': 'Deer Creek 1991',
#    '4813431': 'Don',
#    '7936020': "Don't Cry",
#    '2207173': 'Dreams And Illusions',
#    '9597740': 'Electric Warriors',
#    '8385257': 'Ep',
#    '2301090': 'Ep - Japanese',
#    '8698891': 'Escape To Paris',
#    '3591701': "The Essential Hit's",
#    '29340': 'Estadio Nacional',
#    '6078463': 'Estranged',
#    '2404452': 'Family Tree 2010 Brokers',
#    '5310309': "Freddy's Dead",
#    '7037009': 'Get In The Ring Motherfucker Round 11',
#    '6893377': 'Grandes Exitos',
#    '7295346': 'Greatest Hits',
#    '7392610': 'Hammersmith Odeon 8th October 87',
#    '5554870': "History Of Guns N' Roses",
#    '675134': 'Hit Parader',
#    '825103': 'Holiday Greetings From Geffen Records',
#    '6434345': 'Hollywood Rose',
#    '3995190': 'Ii (peru)',
#    '5667789': 'Illusions On',
#    '4465325': 'Interview',
#    '3964161': 'In The Empire Of The Sun',
#    '9880266': 'In The Jungle',
#    '935293': 'In Tokyio',
#    '958674': "It's So Easy",
#    '2083809': 'I Wanna Watch You Bleed!',
#    '9838892': "Jack Daniel's Tour 1988",
#    '1221554': "Knockin' On Heaven's Door",
#    '4246343': 'The Last American Hero',
#    '512391': 'Legends Of International Rock',
#    '7892913': 'Lies',
#    '8200836': 'Lies And Dollars',
#    '8621111': 'Lies Lies Lies Lies',
#    '222508': 'Limited Edition Interview Picture Disc',
#    '5773984': 'Live',
#    '3193512': 'Live 88 Night Train',
#    '1316985': 'Live And Let Die',
#    '72474': "Live At Biloxi Us Tour '92",
#    '2405347': 'Live At Castle Donnington',
#    '604598': 'Live At Maracana Stadium Rio De Janiero',
#    '2253707': 'Live At The Ritz',
#    '9738762': 'Live Box',
#    '7722732': 'Live Era 1987',
#    '5502745': "Live Era '87",
#    '4104801': 'Live Era 87 To 93',
#    '4905130': 'Live In Chicago',
#    '4676111': 'Live In Concert',
#    '4801519': 'Live Indiana',
#    '6317812': 'Live In London 2012',
#    '3147623': 'Live In Melbourne 1988',
#    '9504471': 'Live In South America',
#    '9601623': 'Live On Air',
#    '3175089': 'Live On Air {picture Disc}',
#    '8594954': 'Live Radio Broadcast',
#    '5048822': 'Make My Day!',
#    '5896640': 'Matrix # 8023',
#    '2356353': "Metal's Petals",
#    '8756852': 'Move To The City',
#    '5964577': 'Music Of',
#    '3324137': 'New Democracy',
#    '6858014': 'New York, New York',
#    '1250678': 'Nice Boys',
#    '686641': 'Nightrain',
#    '7748076': 'Night Train',
#    '6030606': 'November Rain',
#    '2963685': 'Oh My God',
#    '9980062': 'One In A Million',
#    '162680': 'Paradise City',
#    '1555792': 'Patience',
#    '8829314': 'Perkins Palace 1987',
#    '7120107': 'Piano Tribute To',
#    '3935249': 'Practice For Destruction',
#    '3583545': 'Pradise City',
#    '1297713': 'Quot;the Spaghetti Incident',
#    '4609208': 'Reckless Life',
#    '7120762': 'Record Live In Japan February 22nd',
#    '8125636': 'Riverplate Stadium',
#    '3327731': 'Rocket Queen',
#    '8577675': 'Rock In Rio',
#    '7094409': 'Rolling Stone',
#    '1485978': 'Santiago',
#    '1046334': 'Say Your Prayers',
#    '6861977': 'Selected Ballads',
#    '177277': 'Self Destruction',
#    '3794164': "Sex N' Drugs N' Rock N' Roll",
#    '6636952': 'Shadow Of Your Love',
#    '4409196': 'Silent Shots',
#    '4649793': "Since I Don't Have You",
#    '4244741': 'The Spaghetti Incident',
#    '9661917': 'Special',
#    '4386084': 'Stockholm',
#    '533416': 'S/t Self Same Untitled (peru)',
#    '8367972': "Sweet Child O' Mine",
#    '2583088': 'Sympathy For The Devil',
#    '7501003': 'Tales Of Destruction',
#    '8399157': '"the Spaghetti Incident',
#    '6773299': 'Torpo Delux',
#    '1372517': 'Transmissions',
#    '7021271': 'Tylko Rock',
#    '5986107': 'Ultra',
#    '7153677': 'Under The Covers',
#    '5489633': 'Unplugged 1993',
#    '6381631': 'Us 98',
#    '8964139': 'Usa 87',
#    '3180210': 'Use Your Illusion I',
#    '6659373': 'Us We Your Illusion',
#    '2691758': 'The Very Best Ballads',
#    '498469': 'Welcome To The Jungle',
#    '7281461': "We Love The '80s",
#    '5118931': 'Wembley Staduim',
#    '8465418': 'World Tour In Concert',
#    '2370916': 'Yesterdays',
#    '5075976': "You Can't Put Your Arms Around A Memory",
#    '1813842': 'You Could Be Mine',
#    '3240352': 'Rag Doll',
#    '335212': 'Believe In Me',
#    '5149861': 'The Taking',
#    '8663186': '99 Live',
#    '1299980': 'Cure Me...or Kill Me',
#    '7587129': 'Gilby Clarke',
#    '6653338': 'Rubber',
#    '4523480': 'Pressure Drop',
#    '2179065': 'Shuffle It All',
#    '4856275': 'Somebody Knockin',
#    '6610290': 'Magic Carpet Ride',
#    '8054898': 'Been There Lately',
#    '7868749': 'Beggars And Hangers',
#    '4599986': 'Contraband',
#    '6760479': 'Dirty Little Thing',
#    '3011131': 'Fall To Pieces',
#    '8202724': "Rock And F' N Roll Across The Uk",
#    '8469480': 'Slither'}},
#  '5143957': {'MixTape': {'4986401': 'B-line',
#    '6725371': 'Decade',
#    '5554660': 'Untitled'}},
#  '1584158': {'MixTape': {'4008625': 'Demoniac Flagellations',
#    '9933374': 'Into The Eternal Agony',
#    '9082451': 'Peste Negra'}},
#  '1898658': {'MixTape': {'5567786': 'Morphology'}},
#  '3172058': {'MixTape': {'1225022': "Hallo Wir Sind's"}},
#  '1024658': {'MixTape': {'2745016': 'Anna',
#    '86234': 'Celebrate',
#    '7911376': 'Not The Same Girl',
#    '7521015': 'Since You Came In'}},
#  '4134159': {'MixTape': {'7539937': 'Have A Hangover With'}},
#  '9310159': {'MixTape': {'9899397': '??+'}},
#  '5804859': {'MixTape': {'3465161': 'Bubbles', '1640166': 'Lodge'}},
#  '3952206': {'MixTape': {'3715004': 'Missy Generation'}},
#  '6434806': {'MixTape': {'6241019': 'Transit System'}},
#  '3087860': {'MixTape': {'3087860': 'Analyze This Dvd Original Importado Robert De Niro'}},
#  '8882261': {'MixTape': {'5932455': 'A Tribute To Guns N Roses'}},
#  '7897062': {'MixTape': {'8412338': 'Farligt Monster',
#    '7289543': 'Glemte Viser 2010',
#    '8658546': 'Hov',
#    '9906900': 'Klunserbeats',
#    '1965677': 'New Seeland',
#    '2985592': 'So Many Musicians'}},
#  '5795862': {'MixTape': {'3042507': 'Dark Sleep',
#    '7263848': 'Forward The Future'}},
#  '7859463': {'MixTape': {'2085714': 'Analysis Of Time',
#    '7170603': 'Caravan Of Love',
#    '2640292': 'The Euphoria',
#    '5155033': 'Ocean Wave',
#    '6848049': 'Surface Tension'}},
#  '3568563': {'MixTape': {'8793834': 'A Mafia Volta Ao DivÃ'}},
#  '6450064': {'MixTape': {'6424296': 'Hands On Control'}},
#  '865564': {'MixTape': {'7603078': 'Let Me Hear You Stop'}},
#  '13064': {'MixTape': {'7897747': 'Gitana'}},
#  '7502264': {'MixTape': {'9297804': 'I Wish I Was Your Lover'}},
#  '8238964': {'MixTape': {'5881739': 'Many Faces Of'}},
#  '9925365': {'MixTape': {'9902313': 'Days Of Thunder'}},
#  '9106465': {'MixTape': {'3885155': "Guns N' Roses"}},
#  '8651166': {'MixTape': {'3212551': 'Acetic Progress 1',
#    '7683487': 'Sub-bass'}},
#  '1144366': {'MixTape': {'2002179': '14 Years',
#    '2708859': '2002 Tour Passes',
#    '2858811': '2 For 1appetite For',
#    '504866': '87 Destruction Uk',
#    '9577051': 'Aerosmith',
#    '1480194': 'After The Destruction',
#    '1627402': 'At The Perkins Palace',
#    '776965': 'Best Buy Chinese Democracy Promotional Stickers',
#    '5957380': 'The Complete 2008 Chinese Democracy Demos',
#    '1901246': 'Dead Horse',
#    '2395307': 'Destruction 87',
#    '3380840': 'Dramas And Traumas',
#    '8628208': 'Drummer',
#    '5594651': 'Guitar Center Sessions',
#    '8833648': 'In Bed With Axl',
#    '8748246': 'In Their Own Words',
#    '8600458': 'Japan Tour 2017',
#    '3442752': 'Jumpin Jack Flash',
#    '275589': 'Kerrang No.764',
#    '1116455': 'Little Box Of',
#    '7198938': 'Live 88',
#    '1298493': 'Live In Chile 1992',
#    '4790126': 'Live In Japan',
#    '1062974': 'Live Like A Suicide',
#    '431436': 'Live On The Horizon',
#    '2856571': 'Live Usa',
#    '2683337': 'Master Session',
#    '1568648': 'Maximum Audio Biography',
#    '4984968': 'Melody Maker',
#    '6407918': 'More Greatest Hits',
#    '859928': 'Music Life',
#    '6514223': 'A Night At The Ritz',
#    '2937328': 'On Tour Now!',
#    '5742309': 'Parental Advisory Explicit Content',
#    '9338514': 'Paris 2x',
#    '6739161': 'Pretty Tied Up',
#    '3301046': 'Q #30',
#    '8174834': 'Q Magazine',
#    '6043334': 'Raw No.126',
#    '8116248': 'Raw Power',
#    '4695244': "Rock 'n' Roll Comic",
#    '9699452': 'The Singles',
#    '8024565': 'Skulls N Bones',
#    '6861721': "Slash's Snakepit Good 2 Be Alive 2 Vs",
#    '6219227': 'Sounds',
#    '6483705': 'Studyo Imge',
#    '894311': 'Symphathy For The Devil',
#    '1123972': 'Tokyo Tapes',
#    '6771930': 'Use For Illusion Ii',
#    '1801877': 'Vox #13',
#    '3747536': 'Wherever Is Done',
#    '258924': "The World's Most Outrageous Hard Rock Band"}},
#  '2183267': {'MixTape': {'6772866': 'Anal Cannibal',
#    '3157383': 'Chronic Pornoholic',
#    '8210858': 'Five'}},
#  '6031869': {'MixTape': {'6518253': 'Anabolicsteroid'}},
#  '6465869': {'MixTape': {'2014681': 'Análise Microeconomica'}},
#  '4250669': {'MixTape': {'5881739': 'Many Faces Of'}},
#  '3692707': {'MixTape': {'8798788': 'Live At The Cognac A Go Go',
#    '4808944': 'On Turkey'}},
#  '8624307': {'MixTape': {'8624307': 'Anal Terror'}},
#  '6291907': {'MixTape': {'1636467': 'Dance'}},
#  '7428970': {'MixTape': {'4827022': 'Unsurmountable Exhaustion Of Disentombed'}},
#  '2801770': {'MixTape': {'2330877': 'Slave To Time'}},
#  '619670': {'MixTape': {'757193': "G N' R Lies"}},
#  '8927871': {'MixTape': {'9653171': 'Fear And Loathing With The Anal Babes',
#    '3793957': "Old Whores Don't Giggle Much"}},
#  '1328571': {'MixTape': {'7641384': 'City Limits'}},
#  '3144271': {'MixTape': {'416118': 'Odyssey'}},
#  '5498672': {'MixTape': {'2865242': 'C ...is For Cookie!'}},
#  '9757773': {'MixTape': {'8177714': "Dung Slinga'",
#    '3623557': 'Van Allen Belts',
#    '2240792': "Wild 'n' Free"}},
#  '5949373': {'MixTape': {'9821489': 'Circus'}},
#  '2035973': {'MixTape': {'1764302': 'Aaa',
#    '9132293': 'Aad',
#    '3615738': 'Average Luck Charm',
#    '9598536': 'Frequencies',
#    '8199787': 'From Phases Vol. Ii',
#    '4165237': 'Fuel',
#    '2910732': 'Spacid 303',
#    '8727408': 'S/t - Promo Cdr'}},
#  '1887473': {'MixTape': {'8029117': 'Appetite For Destruction'}},
#  '5682573': {'MixTape': {'3885155': "Guns N' Roses"}},
#  '945274': {'MixTape': {'2452012': 'Masters Of Misery Black Sabbath Tribute'}},
#  '5918674': {'MixTape': {'3710138': 'Damage Dealers'}},
#  '45074': {'MixTape': {'4523480': 'Pressure Drop',
#    '2179065': 'Shuffle It All',
#    '4856275': 'Somebody Knockin'}},
#  '3418275': {'MixTape': {'5557408': "Being 'all The Rage' At Snidey Dave's Mobile Disco"}},
#  '6068775': {'MixTape': {'7912328': 'Ng Records Sampler'}},
#  '5235776': {'MixTape': {'3761921': 'Dot 5', '2882561': 'My Way'}},
#  '5295878': {'MixTape': {'5369628': 'Bestial Black Metal Filth',
#    '1190724': 'Ejaculation Of Black Impurity',
#    '2212489': 'Perversions Of Satan',
#    '7425048': 'Profane Fornication Ejaculation',
#    '2389557': 'Sermons Of A Sodomite',
#    '1825268': 'Western Decadence',
#    '5295878': 'Anal Blasphemy'}},
#  '5675979': {'MixTape': {'5675979': 'Anal Warhead',
#    '7110236': 'S/t Self Same Untitled',
#    '655919': 'Time To Die'}},
#  '8141679': {'MixTape': {'5149861': 'The Taking'}},
#  '5501179': {'MixTape': {'9902313': 'Days Of Thunder'}},
#  '1939608': {'MixTape': {'5952117': 'Black Wall 3'}},
#  '3263881': {'MixTape': {'729896': 'Stealth'}},
#  '174181': {'MixTape': {'1322166': 'Station X'}},
#  '6675881': {'MixTape': {'4165824': 'Course Of Life'}},
#  '6489282': {'MixTape': {'1117636': 'Atrocities From Beyond'}},
#  '7867582': {'MixTape': {'6226620': '20 Lat'}},
#  '4685084': {'MixTape': {'2510844': 'Mechanical Restraint'}},
#  '9802485': {'MixTape': {'2132082': 'Acidity 9'}},
#  '6899485': {'MixTape': {'6610290': 'Magic Carpet Ride'}},
#  '8202986': {'MixTape': {'5474017': 'Dakishimete',
#    '4257713': 'Still Life',
#    '7640592': 'Texas Yakenoharaversion'}},
#  '8629686': {'MixTape': {'8975054': 'Progressive Sound'}},
#  '1445687': {'MixTape': {'1985996': 'Music David Holmes'}},
#  '4266287': {'MixTape': {'634149': 'Analía Y Los Accesorios'}},
#  '2660188': {'MixTape': {'3173947': 'Milwaukee Metalfest Xii'}},
#  '7073088': {'MixTape': {'1479026': 'Little Black Box'}},
#  '1970989': {'MixTape': {'3170320': 'Mad Machines'}},
#  '6967289': {'MixTape': {'8861615': 'Disco 006'}},
#  '689189': {'MixTape': {'6516261': 'Fiesta In Acapulco'}},
#  '9309909': {'MixTape': {'5928912': 'Vegan Offensive'}},
#  '1160609': {'MixTape': {'3868130': 'Restoration'}},
#  '2118590': {'MixTape': {'2118590': 'Anal Security Squad'}},
#  '9646090': {'MixTape': {'5471591': 'Computer Controlled'}},
#  '6700791': {'MixTape': {'4715623': 'E.p',
#    '8574477': 'Every Day',
#    '1102536': 'Here We Go',
#    '3664529': 'The Second Chase',
#    '4506802': 'Wait A Second'}},
#  '698593': {'MixTape': {'8018167': 'Ultimate Analogue Test'}},
#  '6533894': {'MixTape': {'5297924': 'Scotland The Rave'}},
#  '5750794': {'MixTape': {'5596556': 'Revolution Day'}},
#  '6839294': {'MixTape': {'9359739': 'Into Darkness'}},
#  '172595': {'MixTape': {'2632958': 'Soulmate',
#    '7814021': 'Analia Y Los Accesorios'}},
#  '140395': {'MixTape': {'1906733': '2005 A.d', '7723660': 'Pimp To Eat'}},
#  '5234995': {'MixTape': {'8952600': 'Music With More Muscles',
#    '3543955': 'Strange Morning In December',
#    '1533002': 'The Wall',
#    '6823208': 'Wall The'}},
#  '2092295': {'MixTape': {'2133547': 'El Análisis Experimental Del Comportamiento'}},
#  '1209496': {'MixTape': {'4717278': '1986-97', '3411729': '86-97'}},
#  '5997296': {'MixTape': {'5887723': 'Rubric Records Sampler'}},
#  '9499196': {'MixTape': {'6610290': 'Magic Carpet Ride'}},
#  '9822697': {'MixTape': {'7193876': 'Sluts'}},
#  '9903897': {'MixTape': {'304136': 'Extinction Level Event'}},
#  '5321497': {'MixTape': {'5203208': 'Alter Ego'}},
#  '6526297': {'MixTape': {'8091049': 'Ana Lucia'}}}

# %%
def getArtistIDX(artistMapData, db, discdf, debug=False):
    if not isinstance(artistMapData, dict):
        raise ValueError("No Artist Map Data")
    if not isinstance(discdf, DataFrame):
        raise ValueError("Not a DataFrame")        
    if not isinstance(artistMapData, dict):
        raise ValueError("artistMapData is not a DB!")

    if debug:
        print("ArtistMapData: {0} and DB: {1}".format(artistMapData, db))
    
    try:
        aMapData = artistMapData.get(db)
    except:
        if debug:
            print("DataBase [{0}] does not exist in artist map data".format(db))
        return None

    try:
        idx = aMapData.get('ID')
    except:
        if debug:
            print("ID and DataBase [{0}] does not exist in artist map data".format(db))
        return None
    
    ## Check
    if idx not in list(discdf.index):
        raise ValueError("ID {0} for {1} is not in the Index of the main DataFrame!".format(idx, db))
    
    return idx        
        

            
def getMusicDatabaseFiles(mdb):
    disc = {}
    for db in mdb.getDBs():
        disc = discogs(db.lower())

    return disc, discdf, artists, artistIDToName, artistNameToID, artistAlbumsDB
# Out:
#   File "<ipython-input-34-58f4bc149f11>", line 47
#     try:
#       ^
# IndentationError: expected an indented block

# %%
mdb = myMusicDBMap(debug=True)
# Out:
# Creating myMusicDBMap()
# /Users/tgadfort/Documents/code/musicdb
#    Loading my music db map: /anaconda3/envs/py37/musicdb/myMusicMap.p
#    DB keys: ['Discogs', 'AllMusic', 'MusicBrainz', 'AceBootlegs', 'RateYourMusic', 'LastFM', 'DatPiff', 'RockCorner', 'CDandLP', 'MusicStack']
# Counter({'Discogs': 3851, 'AllMusic': 3760, 'MusicBrainz': 3622, 'LastFM': 2767, 'DatPiff': 439, 'RockCorner': 313, 'AceBootlegs': 162, 'CDandLP': 66, 'RateYourMusic': 25, 'MusicStack': 5})

# %%
mdb.getNearestArtists("Khalid", cutoff=0.65)
# Out:
# Nearest Matches for: Khalid
# ===> DJ Khaled
#    Discogs        : {'ID': '241513', 'Name': None}
#    AllMusic       : {'ID': '0000660151', 'Name': None}
#    MusicBrainz    : {'ID': '79352929150517086811778730950521425013', 'Name': None}
#    AceBootlegs    : None
#    LastFM         : {'ID': '15998752204', 'Name': None}
#    RateYourMusic  : None
#    DatPiff        : None
#    RockCorner     : None
#    Dummy          : None
#    CDandLP        : None
#    MusicStack     : None

# %%
help(resource_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-ecdf7b95dd06> in <module>
# ----> 1 help(resource_string)
#
# NameError: name 'resource_string' is not defined

# %%
mdb.show()

# %%
mdb.__dict__.keys()

# %%
from ioUtils import getFile

# %%
tmp = getFile("myMusicMap.p")
tmp = mdb.get()

# %%
tmp["AIR"]["Dummy"] = {"ID": '34893584567454455454', 'Name': '39483jfdlkgjfkglshdgrklhatre4riohdfklghrjklhtrjkghdfljksgbfldkgrkjghafkg;hfdshyfga;htrytorhaj;ga;trua;terhg;rthrt8r'}

# %%
mdb.save(tmp)

# %%
mdb.show(tmp)

# %%
mdb.save(myMusicMap)

# %%
mdb.show()

# %%
import sys

# %%
sys

# %%
mdb.__path__
#    packagedir = yourpackage.__path__[0]
#    dirname = pj(os.path.dirname(packagedir), '..', 'share','data')
